# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading in data

# %%
anthropic_df = pd.read_csv("anthropic_mongodb_evals.csv")
bedrock_df = pd.read_csv("final_bedrock_mongodb_evals.csv")

# %%
bedrock_df["query_type"].value_counts()
# Out:
# query_type
# analysis                  11
# anatomical_coordinates     7
# project                    7
# experimental_details       7
# database                   7
# instrument                 5
# subject                    5
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

labels = 'Analysis', "Experiment details","Database level", "Project level", "Anatomical/ Coordinates", "Subject level", "Instrument"
sizes = bedrock_df["query_type"].value_counts().tolist()

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels,
       colors=[
    '#FF9AA2',  # soft pink
    '#FFB7B2',  # light salmon
    '#FFDAC1',  # pale peach
    '#B5EAD7',  # seafoam green
    '#C7CEEA',  # periwinkle
    '#9FB7E0',  # soft blue
    '#D6A2E8',  # lavender
    '#F8C8DC'   # rose
])
# Out:
# ([<matplotlib.patches.Wedge at 0x263dbe29c90>,
#   <matplotlib.patches.Wedge at 0x263dea0cad0>,
#   <matplotlib.patches.Wedge at 0x263dea25810>,
#   <matplotlib.patches.Wedge at 0x263dea26d90>,
#   <matplotlib.patches.Wedge at 0x263dea2c4d0>,
#   <matplotlib.patches.Wedge at 0x263dea2da10>,
#   <matplotlib.patches.Wedge at 0x263dea2ecd0>],
#  [Text(0.8375905603371303, 0.7130512276366491, 'Analysis'),
#   Text(-0.312980348316564, 1.0545346374432858, 'Experiment details'),
#   Text(-1.0196084508273997, 0.41279366153242975, 'Database level'),
#   Text(-0.9584505296697166, -0.539789386868471, 'Project level'),
#   Text(-0.1755597507067299, -1.0858999833924812, 'Anatomical/ Coordinates'),
#   Text(0.6293284653359678, -0.9021893829556386, 'Subject level'),
#   Text(1.043961382809114, -0.3466188558103593, 'Instrument')])

# %%
bedrock_df[["query_type", "response_score", "generation_time", "tool_output_size"]].groupby("query_type").mean()
# Out:
#                         response_score  generation_time  tool_output_size
# query_type
# analysis                      0.545455        40.386014       2382.363636
# anatomical_coordinates        0.714286        21.546845      56671.285714
# database                      0.714286        23.074181       3082.000000
# experimental_details          0.714286        13.644871       4033.571429
# instrument                    1.000000        21.034958       2621.000000
# project                       0.714286        17.494495      13719.571429
# subject                       0.800000        17.290422       1386.000000

# %%
bedrock_df['response_evaluation'].value_counts()
# Out:
# response_evaluation
# CORRECT      35
# ERROR         8
# INCORRECT     6
# Name: count, dtype: int64

# %%
bedrock_df['response_score'].mean()
# Out:
# 0.7142857142857143

# %%
bedrock_df['generation_time'].mean()
# Out:
# 23.79991432734694

# %%
one_hot_df = pd.get_dummies(bedrock_df['response_evaluation'], dtype=float)
bedrock_df = pd.concat([bedrock_df, one_hot_df], axis = 1)
mean_df = bedrock_df[["query_type", "response_score", "generation_time", "tool_output_size", "ERROR"]].groupby("query_type").mean()

# %%
mean_df.columns
# Out:
# Index(['response_score', 'generation_time', 'tool_output_size', 'ERROR',
#        'ERROR'],
#       dtype='object')

# %%
sns.barplot(data=mean_df, x="query_type", y = "response_score")
# Out:
# <Axes: xlabel='query_type', ylabel='response_score'>

# %%
# Define a colorful palette with distinct colors
colors = [
    '#FF9AA2',  # soft pink
    '#FFB7B2',  # light salmon
    '#FFDAC1',  # pale peach
    '#B5EAD7',  # seafoam green
    '#C7CEEA',  # periwinkle
    '#9FB7E0',  # soft blue
    '#D6A2E8',  # lavender
    '#F8C8DC'   # rose
]

# Create a larger figure to give more room for the labels
plt.figure(figsize=(14, 8))

# Create the barplot with wider bars
ax = sns.barplot(
    data=mean_df, 
    x="query_type", 
    y="response_score",
    palette=colors[:len(mean_df.index.unique())]
)

# Fix the overlapping x-axis labels by rotating them and adding padding
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.tight_layout(pad=3.0)  # Adds padding around the plot

# Additional styling
plt.title("Response Scores by Query Type", fontsize=16)
plt.xlabel("Query Type", fontsize=14)
plt.ylabel("Response Score", fontsize=14)

# Ensure sufficient bottom margin for rotated labels
plt.subplots_adjust(bottom=0.25)

# Show the plot
plt.show()
# Out:
# C:\Users\sreya.kumar\AppData\Local\Temp\ipykernel_9916\469135581.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %%
bedrock_df.columns
# Out:
# Index(['input_question', 'target_mongodb_query', 'target_python',
#        'target_answer', 'predicted_answer', 'data_source', 'generation_time',
#        'response_evaluation', 'response_score', 'predicted_mongodb_query',
#        'mongodb_evaluation', 'mongodb_score', 'tool_output_size', 'query_type',
#        'CORRECT', 'ERROR', 'INCORRECT', 'CORRECT', 'ERROR', 'INCORRECT'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 8))

sns.scatterplot(bedrock_df, x="tool_output_size", y="generation_time", hue = "CORRECT", palette=[  '#FF9AA2',  # soft pink

    '#B5EAD7', ])

plt.xscale('log') 
plt.yscale('log')

plt.title('Log-Scaled Scatter Plot comparing MongoDB retrieval size to time taken to generate answer')
plt.xlabel("Tool output size", fontsize=14)
plt.ylabel("Generation time", fontsize=14)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
                           
plt.figure(figsize=(10, 8))

sns.scatterplot(bedrock_df, x="tool_output_size", y="generation_time", hue = "CORRECT")

plt.title('Log-Transformed Scatter Plot')
plt.xlabel('log(X + 1)')
plt.ylabel('log(Y + 1)')
plt.tight_layout()
plt.show()

sns.scatterplot(data=bedrock_df.where(bedrock_df['response_evaluation']!= "ERROR"), x="tool_output_size", y="generation_time", hue = "CORRECT")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 7
#       3 import seaborn as sns
#       5 plt.figure(figsize=(10, 8))
# ----> 7 sns.scatterplot(bedrock_df, x="tool_output_size", y="generation_time", hue = "CORRECT")
#       9 plt.title('Log-Transformed Scatter Plot')
#      10 plt.xlabel('log(X + 1)')
#
# File c:\Users\sreya.kumar\Documents\GitHub\metadata-chatbot\venv\Lib\site-packages\seaborn\relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
#     621     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     622     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File c:\Users\sreya.kumar\Documents\GitHub\metadata-chatbot\venv\Lib\site-packages\seaborn\relational.py:396, in _ScatterPlotter.__init__(self, data, variables, legend)
#     387 def __init__(self, *, data=None, variables={}, legend=None):
#     388
#     389     # TODO this is messy, we want the mapping to be agnostic about
#     390     # the kind of plot to draw, but for the time being we need to set
#     391     # this information so the SizeMapping can use it
#     392     self._default_size_range = (
#     393         np.r_[.5, 2] * np.square(mpl.rcParams["lines.markersize"])
#     394     )
# --> 396     super().__init__(data=data, variables=variables)
#     398     self.legend = legend
#
# File c:\Users\sreya.kumar\Documents\GitHub\metadata-chatbot\venv\Lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File c:\Users\sreya.kumar\Documents\GitHub\metadata-chatbot\venv\Lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File c:\Users\sreya.kumar\Documents\GitHub\metadata-chatbot\venv\Lib\site-packages\seaborn\_core\data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File c:\Users\sreya.kumar\Documents\GitHub\metadata-chatbot\venv\Lib\site-packages\seaborn\_core\data.py:265, in PlotData._assign_variables(self, data, variables)
#     260             ids[key] = id(val)
#     262 # Construct a tidy plot DataFrame. This will convert a number of
#     263 # types automatically, aligning on index in case of pandas objects
#     264 # TODO Note: this fails when variable specs *only* have scalars!
# --> 265 frame = pd.DataFrame(plot_data)
#     267 return frame, names, ids
#
# File c:\Users\sreya.kumar\Documents\GitHub\metadata-chatbot\venv\Lib\site-packages\pandas\core\frame.py:733, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     727     mgr = self._init_mgr(
#     728         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     729     )
#     731 elif isinstance(data, dict):
#     732     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 733     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     734 elif isinstance(data, ma.MaskedArray):
#     735     from numpy.ma import mrecords
#
# File c:\Users\sreya.kumar\Documents\GitHub\metadata-chatbot\venv\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\sreya.kumar\Documents\GitHub\metadata-chatbot\venv\Lib\site-packages\pandas\core\internals\construction.py:119, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     116         index = ensure_index(index)
#     118     # don't force copy because getting jammed in an ndarray anyway
# --> 119     arrays, refs = _homogenize(arrays, index, dtype)
#     120     # _homogenize ensures
#     121     #  - all(len(x) == len(index) for x in arrays)
#     122     #  - all(x.ndim == 1 for x in arrays)
#    (...)
#     125
#     126 else:
#     127     index = ensure_index(index)
#
# File c:\Users\sreya.kumar\Documents\GitHub\metadata-chatbot\venv\Lib\site-packages\pandas\core\internals\construction.py:629, in _homogenize(data, index, dtype)
#     626         val = dict(val)
#     627     val = lib.fast_multiget(val, oindex._values, default=np.nan)
# --> 629 val = sanitize_array(val, index, dtype=dtype, copy=False)
#     630 com.require_length_match(val, index)
#     631 refs.append(None)
#
# File c:\Users\sreya.kumar\Documents\GitHub\metadata-chatbot\venv\Lib\site-packages\pandas\core\construction.py:632, in sanitize_array(data, index, dtype, copy, allow_2d)
#     629 elif hasattr(data, "__array__"):
#     630     # e.g. dask array GH#38645
#     631     data = np.array(data, copy=copy)
# --> 632     return sanitize_array(
#     633         data,
#     634         index=index,
#     635         dtype=dtype,
#     636         copy=False,
#     637         allow_2d=allow_2d,
#     638     )
#     640 else:
#     641     _sanitize_non_ordered(data)
#
# File c:\Users\sreya.kumar\Documents\GitHub\metadata-chatbot\venv\Lib\site-packages\pandas\core\construction.py:658, in sanitize_array(data, index, dtype, copy, allow_2d)
#     655             subarr = cast(np.ndarray, subarr)
#     656             subarr = maybe_infer_to_datetimelike(subarr)
# --> 658 subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     660 if isinstance(subarr, np.ndarray):
#     661     # at this point we should have dtype be None or subarr.dtype == dtype
#     662     dtype = cast(np.dtype, dtype)
#
# File c:\Users\sreya.kumar\Documents\GitHub\metadata-chatbot\venv\Lib\site-packages\pandas\core\construction.py:717, in _sanitize_ndim(result, data, dtype, index, allow_2d)
#     715     if allow_2d:
#     716         return result
# --> 717     raise ValueError(
#     718         f"Data must be 1-dimensional, got ndarray of shape {data.shape} instead"
#     719     )
#     720 if is_object_dtype(dtype) and isinstance(dtype, ExtensionDtype):
#     721     # i.e. NumpyEADtype("O")
#     723     result = com.asarray_tuplesafe(data, dtype=np.dtype("object"))
#
# ValueError: Data must be 1-dimensional, got ndarray of shape (49, 2) instead

# %%
bedrock_df[["tool_output_size", "INCORRECT"]].groupby("INCORRECT").mean()
# Out:
#            tool_output_size
# INCORRECT
# 0.0             7620.767442
# 1.0            43515.500000

# %%
sns.violinplot(data=bedrock_df, x="tool_output_size", y="response_evaluation")
# Out:
# <Axes: xlabel='tool_output_size', ylabel='response_evaluation'>

# %%
anthropic_no_error_df = bedrock_df.where(bedrock_df['response_evaluation']!= "ERROR")
print(f"The mean answer generation time through anthropic is {anthropic_no_error_df.loc[:, 'generation_time'].mean()}")
plt.hist(anthropic_no_error_df['generation_time'], range = (0,60))
plt.show()
# Out:
# The mean answer generation time through anthropic is 28.638922000975608

# %%
# Create a larger figure to give more room for the labels
plt.figure(figsize=(14, 8))

# Create the barplot with wider bars
ax = sns.histplot(data=anthropic_no_error_df, x="generation_time", hue="CORRECT", multiple = "stack", palette=[  '#FFB7B2', '#B5EAD7',] )


# Fix the overlapping x-axis labels by rotating them and adding padding
plt.xticks(rotation=45, ha='right', fontsize=12)
plt.tight_layout(pad=3.0)  # Adds padding around the plot

# Additional styling
plt.title("Time taken to generate answer", fontsize=16)
plt.xlabel("Generation time (s)", fontsize=14)
plt.ylabel("Count", fontsize=14)

# Ensure sufficient bottom margin for rotated labels
plt.subplots_adjust(bottom=0.25)

# Show the plot
plt.show()

# %% [markdown]
# ### Preprocessing to combine dfs

# %%
combined_df = anthropic_df.rename(
    columns={
        "generation_time": "anthropic_generation_time",
        "mongodb_evaluation": "anthropic_mongodb_evaluation",
        "mongodb_score": "anthropic_mongodb_score",
        "response_evaluation": "anthropic_response_evaluation",
        "response_score": "anthropic_response_score",
    }
)

bedrock_df = bedrock_df.rename(
    columns={
        "generation_time": "bedrock_generation_time",
        "mongodb_evaluation": "bedrock_mongodb_evaluation",
        "mongodb_score": "bedrock_mongodb_score",
        "response_evaluation": "bedrock_response_evaluation",
        "response_score": "bedrock_response_score",
    }
)

combined_df["bedrock_generation_time"] = bedrock_df["bedrock_generation_time"]
combined_df["bedrock_mongodb_evaluation"] = bedrock_df["bedrock_mongodb_evaluation"]
combined_df["bedrock_mongodb_score"] = bedrock_df["bedrock_mongodb_score"]
combined_df["bedrock_response_evaluation"] = bedrock_df["bedrock_response_evaluation"]
combined_df["bedrock_response_score"] = bedrock_df["bedrock_response_score"]

combined_df.head(5)
# Out:
#                                       input_question  \
# 0  for mouse 721291 can you make a table of sessi...
# 1                         Tell me about mouse 747107
# 2  How many records use the session.data_streams....
# 3  can you tell me how many sessions exist for 77...
# 4  Find how many experimental sessions conducted ...
#
#                                 target_mongodb_query  \
# 0  {"filter":{"subject.subject_id":"721291"},"pro...
# 1                   {"subject.subject_id": "747107"}
# 2  {"agg_pipeline":[{"$match":{"session.data_stre...
# 3  filter = {"subject.subject_id": "775745"}\npro...
# 4  {"agg_pipeline":[{"$match":{"$or":[{"acquisiti...
#
#                                        target_answer  \
# 0  Sessions for Mouse 721291\n Session, Date, Ses...
# 1  Mouse 747107 is a female Mus musculus with the...
# 2  there are 5488 records with session.data_strea...
# 3           There are 50 sessions for subject 775745
# 4         86 sessions were conducted by Marton Rozsa
#
#                                     predicted_answer  \
# 0  I'll create an aggregation pipeline to retriev...
# 1  I'll help you retrieve the details for mouse 7...
# 2  Here's a query to count records that have a no...
# 3  I'll help you count the number of sessions for...
# 4  Error: Error code: 400 - {'type': 'error', 'er...
#
#                              predicted_mongodb_query  \
# 0  {'filter': {'subject.subject_id': '721291'}, '...
# 1  {'filter': {'subject.subject_id': '747107'}, '...
# 2  {'agg_pipeline': [{'$match': {'session.data_st...
# 3  {'agg_pipeline': [{'$match': {'subject.subject...
# 4  Error: Error code: 400 - {'type': 'error', 'er...
#
#    anthropic_generation_time anthropic_mongodb_evaluation  \
# 0                  45.258800                      CORRECT
# 1                  11.560473                      CORRECT
# 2                  10.611998                      CORRECT
# 3                  10.799716                      CORRECT
# 4                  10.799716                        ERROR
#
#    anthropic_mongodb_score anthropic_response_evaluation  \
# 0                      1.0                     INCORRECT
# 1                      1.0                     INCORRECT
# 2                      1.0                       CORRECT
# 3                      1.0                     INCORRECT
# 4                      0.0                         ERROR
#
#    anthropic_response_score  bedrock_generation_time  \
# 0                       0.0                27.374631
# 1                       0.0                21.749024
# 2                       1.0                19.400605
# 3                       0.0                15.529134
# 4                       0.0                15.529134
#
#   bedrock_mongodb_evaluation  bedrock_mongodb_score  \
# 0                    CORRECT                    1.0
# 1                    CORRECT                    1.0
# 2                    CORRECT                    1.0
# 3                    CORRECT                    1.0
# 4                      ERROR                    0.0
#
#   bedrock_response_evaluation  bedrock_response_score
# 0                   INCORRECT                     0.0
# 1                     CORRECT                     1.0
# 2                     CORRECT                     1.0
# 3                   INCORRECT                     0.0
# 4                       ERROR                     0.0

# %%
combined_df.shape
# Out:
# (45, 15)

# %% [markdown]
# ## Analysis

# %%
combined_df['anthropic_mongodb_evaluation'].value_counts()
# Out:
# anthropic_mongodb_evaluation
# CORRECT      22
# INCORRECT    14
# ERROR         9
# Name: count, dtype: int64

# %%
combined_df['bedrock_mongodb_evaluation'].value_counts()
# Out:
# bedrock_mongodb_evaluation
# CORRECT      23
# INCORRECT    12
# ERROR        10
# Name: count, dtype: int64

# %%
combined_df['anthropic_response_evaluation'].value_counts()
# Out:
# anthropic_response_evaluation
# INCORRECT    31
# ERROR         8
# CORRECT       6
# Name: count, dtype: int64

# %%
combined_df['bedrock_response_evaluation'].value_counts()
# Out:
# bedrock_response_evaluation
# CORRECT      24
# INCORRECT    11
# ERROR        10
# Name: count, dtype: int64
